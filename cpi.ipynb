# %% [markdown]
# <a href="https://colab.research.google.com/github/paulevalentine/financial/blob/master/cpi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %%
data = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Data/series-150520.csv')

# %%
data.columns=['Date', 'Value']
data.index=data.Date

# %%
plt.figure(figsize=[25,7])
data.Value.plot()
plt.grid(linestyle=':')
plt.ylabel('Percentage')
# Out:
# Text(0, 0.5, 'Percentage')
